# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.385586    35.250713    26.768006    28.908804    855215656
# 2007-10-08    30.727669    33.480121    30.534513    33.480121    126671715
# 2007-10-09    32.820171    33.109902    29.085851    30.743759    116725709
# 2007-10-10    33.126011    33.802053    32.836280    33.673282     67931378
# 2007-10-11    36.828129    38.630905    32.836270    38.630905    106320954

# %%
df.shape
# Out:
# (4208, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4208 entries, 2007-10-05 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4208 non-null   float64
#  1   (High, POWERGRID.NS)    4208 non-null   float64
#  2   (Low, POWERGRID.NS)     4208 non-null   float64
#  3   (Open, POWERGRID.NS)    4208 non-null   float64
#  4   (Volume, POWERGRID.NS)  4208 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 197.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4208.000000  4208.000000  4208.000000  4208.000000  4.208000e+03
# mean      79.255945    80.286305    78.238144    79.292804  1.188963e+07
# std       63.621688    64.365266    62.829875    63.603317  2.061999e+07
# min       18.908407    20.212435    16.952366    20.114632  0.000000e+00
# 25%       36.349714    36.923186    35.812882    36.386935  4.799653e+06
# 50%       55.232323    55.870057    54.493156    55.338369  8.344398e+06
# 75%       82.704763    83.691970    81.724070    82.727261  1.362032e+07
# max      356.113861   356.893408   348.074624   354.749603  8.552157e+08

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()
# Out:
#     Price        Date              Close                High  \
# 0  Ticker         NaN       POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05  32.38558578491211   35.25071281473011
# 2       1  2007-10-08  30.72766876220703   33.48012071257007
# 3       2  2007-10-09  32.82017135620117  33.109902182328575
# 4       3  2007-10-10  33.12601089477539   33.80205264632212
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  26.768006081918546  28.908803575805525     855215656
# 2  30.534513396740614   33.48012071257007     126671715
# 3  29.085850801739035   30.74375909726689     116725709
# 4    32.8362799630773   33.67328164530978      67931378

# %%
# Candlesticks 
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'], 
                                    high = data01['High'],
                                    low = data01['Low'], 
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Candlesticks
#       2 import plotly.graph_objects as go
# ----> 4 fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
#       5                                     high = data01['High'],
#       6                                     low = data01['Low'],
#       7                                     close = data01['Close'])])
#       8 fig.update_layout(xaxis_rangeslider_visible=False)
#       9 fig.show()
#
# NameError: name 'data01' is not defined

# %%
df = df.drop([col for col in columns_to_drop if col in df.columns], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = df.drop([col for col in columns_to_drop if col in df.columns], axis=1)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# Price         Close         High          Low         Open       Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0         32.385586    35.250713    26.768006    28.908804    855215656
# 1         30.727669    33.480121    30.534513    33.480121    126671715
# 2         32.820171    33.109902    29.085851    30.743759    116725709
# 3         33.126011    33.802053    32.836280    33.673282     67931378
# 4         36.828129    38.630905    32.836270    38.630905    106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4203      324.993564
# 4204      325.235135
# 4205      325.471087
# 4206      325.670631
# 4207      325.807062
#
# [4208 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2945, 1)

# %%
data_testing.shape
# Out:
# (1263, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808621],
#        [0.17371831],
#        [0.2044737 ],
#        ...,
#        [0.90774465],
#        [0.86000384],
#        [0.87299659]])

# %%
data_training_array.shape[0]
# Out:
# 2945

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2845, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# LSTM Input -> 3D Array (batch_size, time_steps, seq_len)
# LSTM 2D OR 3D
# 2D -> (batch_sizem units)
# 3D -> (batch_size, time_steps, units)

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# C:\Users\ujjav\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0894
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - loss: 0.0894
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0095
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - loss: 0.0095
# Epoch 3/50
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - loss: 0.0076
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - loss: 0.0076
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.0077
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.0077
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - loss: 0.0064
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - loss: 0.0064
# Epoch 6/50
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 124ms/step - loss: 0.0054
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 124ms/step - loss: 0.0054
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 0.0075
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 0.0075
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step - loss: 0.0053
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step - loss: 0.0053
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 151ms/step - loss: 0.0047
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 151ms/step - loss: 0.0047
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - loss: 0.0043
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - loss: 0.0043
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - loss: 0.0043
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - loss: 0.0043
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 139ms/step - loss: 0.0043
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 139ms/step - loss: 0.0043
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - loss: 0.0045
# Epoch 14/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - loss: 0.0045
# Epoch 14/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 138ms/step - loss: 0.0039
# Epoch 15/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 138ms/step - loss: 0.0039
# Epoch 15/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - loss: 0.0040
# Epoch 16/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - loss: 0.0040
# Epoch 16/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0035
# Epoch 17/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0035
# Epoch 17/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0036
# Epoch 18/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0036
# Epoch 18/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 137ms/step - loss: 0.0032
# Epoch 19/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 137ms/step - loss: 0.0032
# Epoch 19/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0035
# Epoch 20/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0035
# Epoch 20/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - loss: 0.0035
# Epoch 21/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 158ms/step - loss: 0.0035
# Epoch 21/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0030
# Epoch 22/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0030
# Epoch 22/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - loss: 0.0034
# Epoch 23/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - loss: 0.0034
# Epoch 23/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - loss: 0.0030
# Epoch 24/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - loss: 0.0030
# Epoch 24/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - loss: 0.0029
# Epoch 25/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - loss: 0.0029
# Epoch 25/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0026
# Epoch 26/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0026
# Epoch 26/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0027
# Epoch 27/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0027
# Epoch 27/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0026
# Epoch 28/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0026
# Epoch 28/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0036
# Epoch 29/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - loss: 0.0036
# Epoch 29/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 30/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 30/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0026
# Epoch 31/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0026
# Epoch 31/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 32/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 32/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0024
# Epoch 33/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0024
# Epoch 33/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 34/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0025
# Epoch 34/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0022
# Epoch 35/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0022
# Epoch 35/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0023
# Epoch 36/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0023
# Epoch 36/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0024
# Epoch 37/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0024
# Epoch 37/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - loss: 0.0024
# Epoch 38/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - loss: 0.0024
# Epoch 38/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 154ms/step - loss: 0.0024
# Epoch 39/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 154ms/step - loss: 0.0024
# Epoch 39/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0022
# Epoch 40/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0022
# Epoch 40/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 165ms/step - loss: 0.0023
# Epoch 41/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 15s 165ms/step - loss: 0.0023
# Epoch 41/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0025
# Epoch 42/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0025
# Epoch 42/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0021
# Epoch 43/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0021
# Epoch 43/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0025
# Epoch 44/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0025
# Epoch 44/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0022
# Epoch 45/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0022
# Epoch 45/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0021
# Epoch 46/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0021
# Epoch 46/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0022
# Epoch 47/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - loss: 0.0022
# Epoch 47/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0022
# Epoch 48/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0022
# Epoch 48/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0022
# Epoch 49/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0022
# Epoch 49/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0022
# Epoch 50/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 150ms/step - loss: 0.0022
# Epoch 50/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0021

# %%
past_100_days = data_training.tail(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 past_100_days = data_training.tail(100)
#
# NameError: name 'data_training' is not defined

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28428\3299050086.py in ?()
# ----> 1 final_df = past_100_days.append(data_testing, ignore_index = True)
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
final_df.head()
# Out:
# Ticker  POWERGRID.NS
# 0         104.850029
# 1         106.987526
# 2         107.353149
# 3         107.128151
# 4         107.746902

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1263, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 40/40 [==============================] - 5s 112ms/step

# %%
y_predicted.shape
# Out:
# (1263, 1)

# %%
scaler.scale_
# Out:
# array([0.0035166])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
